# %%
import argparse
from Bio import Entrez
import pandas as pd
from datetime import date
from datetime import datetime
import re

# %%
today = date.today()
date = today.strftime("%Y_%m_%d")
now = datetime.now()
time = now.strftime("at_%H_%M")
filename_prefix = "GEO_compare_test_" + str(date) + "_" + str(time)
filename_prefix
# Out:
# 'GEO_compare_test_2022_02_24_at_19_52'

# %%
output = filename_prefix
old = "/Users/Cardiff/Downloads/HiChIP_Database_GEO/HiChIP_Databases.xlsx"
new = "/Users/Cardiff/Downloads/HiChIP_Database_GEO/GEO_query_test_2022_02_24_at_16_33.xlsx"

# %%
old_df = pd.read_excel(old)
new_df = pd.read_excel(new)

# %%
# def geo_compare(old, new, output):
#     print("Arguements given are:", old, new, output)
#     old_df = pd.read_excel(old)
#     new_df = pd.read_excel(new)
#     # old_df["Year"] = old_df["Year"].astype(str)
#     old_df=old_df.applymap(str)
#     old_df["Year"] = old_df["Year"].str[:4]
#     new_df=new_df.applymap(str)
#     if "Potential HiChIP" not in old_df.columns:
#         old_df["Potential HiChIP"] = ""
#         old_df = old_df[['Paper Title', 'Journal', 'Authors', 'Year', 'GEO / Data link',
#            'Any other information', 'Organism', 'Tissue/Cell Line',
#            'Potential HiChIP', 'Other matched data', 'Presenter']]
#     merged_df = old_df.merge(new_df, how='outer', sort=False)
#     merged_df.replace({'nan': ""}, inplace=True)
#     print(merged_df)
#     merged_df.to_excel(filename_prefix+".xlsx", index=False) 
#     print("Finished and saved to", filename_prefix+".xlsx")

# %%
# geo_compare(old, new, filename_prefix)

# %%
GEO_pattern = re.compile('GSE[0123456789]+')

# %%
old_GEOs = set()
for x in old_df['GEO / Data link'].tolist():
    GEO = GEO_pattern.findall(x)
    old_GEOs.update(GEO)

# %%
new_GEOs = set()
for x in new_df['GEO / Data link'].tolist():
    GEO = GEO_pattern.findall(x)
    new_GEOs.update(GEO)

# %%
differences_GEOs = new_GEOs.difference(old_GEOs)

# %%
bools = []
for x in new_df['GEO / Data link'].tolist():
    if x in differences_GEOs: bools.append(True)
    else: bools.append(False)

# %%
differences_df = new_df.loc[bools]

# %%
differences_df.fillna("",inplace=True)
differences_df
# Out:
# /Users/Cardiff/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
#                                           Paper Title  \
# 0   A primed immune transcriptional program is act...
# 1   A small set of accessible enhancers enables br...
# 4   CTCF HiChIP data in A673 Ewing sarcoma cell li...
# 7   Dynamic chromatin regulatory landscape of huma...
# 9          Epigenomics landscape of colorectal cancer
# 11      Expression profiling of Ewing sarcoma samples
# 13  Gibbin (AHDC1) regulates the mesoderm to patte...
# 14  H3K27ac HiChIP of germinal center B cell-deriv...
# 15  Hi-ChIP dataset for epigenomics landscape of c...
# 22  Locus-specific chromatin profiling of evolutio...
# ...

# %%
differences_df.to_excel(output+".xlsx", index=False)
