# %%
import os
from Bio import Entrez
import pandas as pd
from datetime import date
from datetime import datetime
import re

# %% [markdown]
# ## Make an Output Directory and Get the Input Files

# %%
# make an output directory
outdir = 'results/hichip_db/'
os.makedirs(outdir, exist_ok=True)

# get the newest and second newest paper tables
old = "/Users/Cardiff/Downloads/geo-paper-tracker/results/hichip_db/HiChIP_Databases_Mar_8.xlsx"
new = "/Users/Cardiff/Downloads/geo-paper-tracker/results/hichip_db/GEO_Query.2022_03_09_11_53.xlsx"
old_df = pd.read_excel(old)
new_df = pd.read_excel(new)

# %% [markdown]
# ##  Compare Old and New GEO IDs

# %%
# make a regex to extract GEO ID
GEO_pattern = re.compile('GSE[0123456789]+')

# make a set of old GEO IDs
old_GEOs = set()
for x in old_df['GEO / Data link'].tolist():
    GEO = GEO_pattern.findall(x)
    old_GEOs.update(GEO)

# make a set of new GEO IDs
new_GEOs = set()
for x in new_df['GEO / Data link'].tolist():
    GEO = GEO_pattern.findall(x)
    new_GEOs.update(GEO)

# compare the sets of GEO IDs
differences_GEOs = new_GEOs.difference(old_GEOs)

# %%
# create an indicate column of papers whose GEO ID is not in the old table 
bools = []
for geoid_strings in new_df['GEO / Data link'].tolist():
    
    geo_status = False
    for geoid in geoid_strings.split():
        if geoid in differences_GEOs:
            geo_status = True
            break
    bools.append(geo_status)

differences_df = new_df.loc[bools]

# replace na with empty string
differences_df.fillna("", inplace=True)
# Out:
# /Users/Cardiff/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
differences_df
# Out:
#                                            Paper Title            Journal  \
# 2    A primed immune transcriptional program is act...             Neuron
# 3    A small set of accessible enhancers enables br...  Nucleic Acids Res
# 4    A topological atlas reveals layers of genome r...               Cell
# 5    Allelic specificity of IGH-DUX4 translocation ...         Nat Commun
# 6    Allelic specificity of IGH-DUX4 translocation ...         Nat Commun
# ..                                                 ...                ...
# 119  UTX condensation underlies its tumor suppressi...             Nature
# 120  Widespread Long-range Cis-Regulatory Elements ...         Nat Plants
# 121  YY1 is a structural regulator of enhancer-prom...               Cell
# 123  cLoops2: a full-stack comprehensive analytical...  Nucleic Acids Res
# 124  ecDNA hubs drive cooperative intermolecular on...             Nature
#
#               Authors  Year                                           DOI  \
# 2       Meijer et al.  2022  https://doi.org/10.1016/j.neuron.2021.12.034
# 3       Zaurin et al.  2021          https://doi.org/10.1093/nar/gkab1125
# 4    Johnstone et al.  2020    https://doi.org/10.1016/j.cell.2020.07.030
# 5         Tian et al.  2019    https://doi.org/10.1038/s41467-019-10637-8
# 6         Tian et al.  2019    https://doi.org/10.1038/s41467-019-10637-8
# ..                ...   ...                                           ...
# 119        Shi et al.  2021    https://doi.org/10.1038/s41586-021-03903-7
# 120      Ricci et al.  2019     https://doi.org/10.1038/s41477-019-0547-0
# 121  Weintraub et al.  2017    https://doi.org/10.1016/j.cell.2017.11.008
# 123        Cao et al.  2021          https://doi.org/10.1093/nar/gkab1233
# 124       Hung et al.  2020    https://doi.org/10.1038/s41586-021-04116-8
#
#           GEO / Data link                              Any other information  \
# 2    GSE166177\nGSE166179  Other\nGenome binding/occupancy profiling by h...
# 3               GSE179666  Expression profiling by high throughput sequen...
# 4               GSE133928  Genome binding/occupancy profiling by high thr...
# 5               GSE115494  Genome binding/occupancy profiling by high thr...
# 6               GSE115492  Genome binding/occupancy profiling by high thr...
# ..                    ...                                                ...
# 119             GSE149420  Genome binding/occupancy profiling by high thr...
# 120             GSE120304  Expression profiling by high throughput sequen...
# 121    GSE99521\nGSE99519  Expression profiling by high throughput sequen...
# 123             GSE179010                                              Other
# 124  GSE159986\nGSE159985  Genome binding/occupancy profiling by high thr...
#
#                        Organism Tissue/Cell Line  \
# 2                  Mus musculus
# 3                  Homo sapiens
# 4                  Homo sapiens
# 5                  Homo sapiens
# 6                  Homo sapiens
# ..                          ...              ...
# 119  Homo sapiens; Mus musculus
# 120                    Zea mays
# 121  Homo sapiens; Mus musculus
# 123                Homo sapiens
# 124                Homo sapiens
#
#                                     Other matched data Presenter  Date Added
# 2    GSM5065199: H3K27ac_HiChIP_IFN_mOPC_rep1\nGSM5...            2022-03-09
# 3    GSM5425946: aHiChIP PR T0\nGSM5425945: aHiChIP...            2022-03-09
# 4    GSM3930281: MGH1904_HiChIP\nGSM3930275: BRD316...            2022-03-09
# 5                           GSM3179300: H3K27Ac HiChip            2022-03-09
# 6                           GSM3179300: H3K27Ac HiChip            2022-03-09
# ..                                                 ...       ...         ...
# 119  GSM5379698: HiChIP_H3K27ac_WT\nGSM5379695: HiC...            2022-03-09
# 120  GSM4284450: HiChIP B73 leaf H3K4me3\nGSM428445...            2022-03-09
# 121  GSM2774003: HiChIP_mES_C3_UT_H3K27ac_rep1\nGSM...            2022-03-09
# 123  GSM5403564: ChIC_GM12878_IgG_Rep1\nGSM5403558:...            2022-03-09
# 124  GSM5334235: SNU16_dCas9_KRAB_H3K27ac_HiChIP_re...            2022-03-09
#
# [106 rows x 12 columns]

# %% [markdown]
# ## Save the Output File

# %%
# determining the current year, month and day
today = date.today()
date_str = today.strftime("%Y_%m_%d")

# determining current hour and minute
now = datetime.now()
time_str = now.strftime("%H_%M")

# setting the output filename
output = os.path.join(outdir, "GEO_Compare.{}_{}".format(date_str, time_str))

# %%
output
# Out:
# 'results/hichip_db/GEO_Compare.2022_03_09_11_55'

# %%
differences_df.to_excel(output + ".xlsx", index=False)
