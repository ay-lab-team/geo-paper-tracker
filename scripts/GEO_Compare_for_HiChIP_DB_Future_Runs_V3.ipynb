# %%
import os
import glob
from Bio import Entrez
import pandas as pd
from datetime import date
from datetime import datetime
import re

# %% [markdown]
# ## Find the HiChIP_Database Google Sheet (Old) and the Newly Queried Excel Sheet (New)

# %%
# make an output directory
outdir = 'results/hichip_db/'
os.makedirs(outdir, exist_ok=True)

# get a list of filenames containing 'HiChIP_Databases' and another containing 'Query' 
cwd = os.getcwd()
Query_files = []
os.chdir(cwd)

glob_path = os.path.join(outdir, '*.xlsx')
for file in glob.glob(glob_path):
        
    if 'Query'.casefold() in file.casefold():
        Query_files.append(file)

# sort the two lists in descending order
Query_files.sort(key=str.lower, reverse=True)
old_file = cwd + "/" + Query_files[1]
new_file = cwd + "/" + Query_files[0]

# %%
# get the newest and second newest paper tables
old_df = pd.read_excel(old_file)
new_df = pd.read_excel(new_file)

# %% [markdown]
# ##  Compare Old and New GEO IDs

# %%
# make a regex to extract GEO ID
GEO_pattern = re.compile('GSE[0123456789]+')

# make a set of old GEO IDs
old_GEOs = set()
for x in old_df['GEO / Data link'].tolist():
    GEO = GEO_pattern.findall(x)
    old_GEOs.update(GEO)

# make a set of new GEO IDs
new_GEOs = set()
for x in new_df['GEO / Data link'].tolist():
    GEO = GEO_pattern.findall(x)
    new_GEOs.update(GEO)

# compare the sets of GEO IDs
differences_GEOs = new_GEOs.difference(old_GEOs)

# %%
# create an indicate column of papers whose GEO ID is not in the old table 
bools = []
for geoid_strings in new_df['GEO / Data link'].tolist():
    
    geo_status = False
    for geoid in geoid_strings.split():
        if geoid in differences_GEOs:
            geo_status = True
            break
    bools.append(geo_status)

differences_df = new_df.loc[bools]

# replace na with empty string
differences_df.fillna("", inplace=True)
# Out:
# /tmp/ipykernel_63603/1355104263.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   differences_df.fillna("", inplace=True)

# %%
differences_df
# Out:
#                                           Paper Title  \
# 0   A primed immune transcriptional program is act...
# 1   A small set of accessible enhancers enables br...
# 2   BCL11B enhancer hijacking defines a subtype of...
# 3   CTCF HiChIP data in A673 Ewing sarcoma cell li...
# 5   Cohesin protein STAG2 regulates expression of ...
# 6   Dynamic chromatin regulatory landscape of huma...
# 7   EBF1 nuclear repositioning instructs chromatin...
# 8   EWSR1-ATF1 dependent 3D connectivity regulates...
# 9          Epigenomics landscape of colorectal cancer
# 10  Epstein-Barr virus nuclear antigen 2 (EBNA2) e...
# 11      Expression profiling of Ewing sarcoma samples
# 12  Genome-wide maps of chromatin state in HCT116 ...
# 13  Gibbin (AHDC1) regulates the mesoderm to patte...
# 14  H3K27ac HiChIP of germinal center B cell-deriv...
# 15  Hi-ChIP dataset for epigenomics landscape of c...
# 17  Identification of enhancer-promoter contacts i...
# 19  KLF4 Recruits SWI/SNF to Increase Chromatin Ac...
# 21  Lineage transcription factors ASCL1, NKX2-1, a...
# 22  Locus-specific chromatin profiling of evolutio...
# 24               Role of GR in protection of podocyte
# 25  STAG2 promotes CTCF-anchored loop extrusion an...
# 26  Single-nucleotide-level mapping of DNA regulat...
# 27  Specific genomic features underlie the co-opti...
# 28  Systematic Functional Characterization of Anti...
# 29  Targeting SWI/SNF ATPases in enhancer-addicted...
# 30  The Xia-Gibbs Syndrome protein Gibbin regulate...
# 31  The dynamic, combinatorial cis-regulatory lexi...
# 32          The effect of STAG2 loss in Ewing sarcoma
# 33  The transcriptional equilibration between andr...
# 34  UTX condensation underlies its tumor suppressi...
# 35  cLoops2: a full-stack comprehensive analytical...
#
#                              DOI                   Journal            Authors  \
# 0   10.1016/j.neuron.2021.12.034                    Neuron      Meijer et al.
# 1           10.1093/nar/gkab1125         Nucleic Acids Res      Zaurin et al.
# 2   10.1158/2159-8290.CD-21-0145             Cancer Discov  Montefiori et al.
# 3    10.1016/j.ccell.2021.04.001               Cancer Cell      Surdez et al.
# 5
# 6        10.1073/pnas.2104758118  Proc Natl Acad Sci U S A     Gennert et al.
# 7   10.1016/j.molcel.2022.01.015                  Mol Cell        Zhou et al.
# 8
# 9     10.1136/gutjnl-2020-322835                       Gut      Orouji et al.
# 10         10.1101/gr.264705.120                Genome Res        Hong et al.
# 11   10.1016/j.ccell.2021.04.001               Cancer Cell      Surdez et al.
# 12          10.1093/nar/gkab1242         Nucleic Acids Res         Lee et al.
# 13
# 14
# 15    10.1136/gutjnl-2020-322835                       Gut      Orouji et al.
# 17    10.1038/s41467-021-27055-4                Nat Commun         Liu et al.
# 19
# 21    10.1016/j.isci.2021.102953                  iScience        Pozo et al.
# 22          10.1093/nar/gkab1232         Nucleic Acids Res      Taylor et al.
# 24    10.1038/s42003-021-02209-8               Commun Biol        Wang et al.
# 25   10.1016/j.ccell.2021.04.001               Cancer Cell      Surdez et al.
# 26    10.1038/s41588-021-00861-8                 Nat Genet       Cheng et al.
# 27
# 28
# 29    10.1038/s41586-021-04230-7                    Nature     Delgado et al.
# 30
# 31    10.1038/s41588-021-00947-3                 Nat Genet         Kim et al.
# 32   10.1016/j.ccell.2021.05.007               Cancer Cell       Adane et al.
# 33    10.1038/s41467-021-27077-y                Nat Commun         Guo et al.
# 34    10.1038/s41586-021-03903-7                    Nature         Shi et al.
# 35          10.1093/nar/gkab1233         Nucleic Acids Res         Cao et al.
#
#     Year                                    GEO / Data link  \
# 0   2021                                          GSE166179
# 1   2021                                          GSE179666
# 2   2021                               GSE165209\nGSE165207
# 3   2021                                          GSE156650
# 5   2022  GSE186055\nGSE156773\nGSE156772\nGSE156771\nGS...
# 6   2021                                          GSE168881
# 7   2022                    GSE173872\nGSE173871\nGSE173843
# 8   2022                               GSE180198\nGSE180194
# 9   2021                                          GSE136889
# 10  2021  GSE179755\nGSE178131\nGSE177046\nGSE176421\nGS...
# 11  2021                                          GSE142162
# 12  2022                               GSE179545\nGSE179544
# 13  2022                                          GSE180495
# 14  2021                                          GSE183797
# 15  2021                                          GSE136629
# 17  2021                               GSE166232\nGSE166234
# 19  2021                               GSE153013\nGSE152900
# 21  2021                               GSE151002\nGSE151001
# 22  2021                                          GSE182304
# 24  2021                                          GSE117888
# 25  2021                                          GSE133228
# 26  2021                                          GSE168719
# 27  2022                                          GSE192951
# 28  2021                                          GSE148958
# 29  2021                               GSE171592\nGSE171591
# 30  2022                                          GSE181971
# 31  2021                               GSE181416\nGSE158642
# 32  2021                    GSE165977\nGSE113100\nGSE116495
# 33  2021                               GSE157974\nGSE157107
# 34  2021                                          GSE149420
# 35  2021                                          GSE179010
#
#                                 Any other information  \
# 0   Genome binding/occupancy profiling by high thr...
# 1   Expression profiling by high throughput sequen...
# 2   Genome binding/occupancy profiling by high thr...
# 3                                               Other
# 5   Other\nExpression profiling by high throughput...
# 6                                               Other
# 7   Expression profiling by high throughput sequen...
# 8   Genome binding/occupancy profiling by high thr...
# 9   Genome binding/occupancy profiling by high thr...
# 10  Other\nGenome variation profiling by SNP array...
# 11                      Expression profiling by array
# 12  Genome binding/occupancy profiling by high thr...
# 13  Expression profiling by high throughput sequen...
# 14                                              Other
# 15  Genome binding/occupancy profiling by high thr...
# 17  Other\nGenome binding/occupancy profiling by h...
# 19  Other\nExpression profiling by high throughput...
# 21  Genome binding/occupancy profiling by high thr...
# 22                                              Other
# 24  Expression profiling by high throughput sequen...
# 25  Expression profiling by high throughput sequen...
# 26  Genome binding/occupancy profiling by high thr...
# 27  Expression profiling by high throughput sequen...
# 28  Expression profiling by high throughput sequen...
# 29  Expression profiling by high throughput sequen...
# 30                                              Other
# 31  Expression profiling by high throughput sequen...
# 32  Genome binding/occupancy profiling by high thr...
# 33  Other\nExpression profiling by high throughput...
# 34  Genome binding/occupancy profiling by high thr...
# 35                                              Other
#
#                           Organism Tissue/Cell Line Potential HiChIP  \
# 0       Mus musculus; Homo sapiens                               Yes
# 1                     Homo sapiens                               Yes
# 2                     Homo sapiens                               Yes
# 3                     Homo sapiens                               Yes
# 5                     Homo sapiens                             Maybe
# 6                     Homo sapiens                             Maybe
# 7                     Homo sapiens                               Yes
# 8                     Homo sapiens                               Yes
# 9                     Homo sapiens                               Yes
# 10                    Homo sapiens                               Yes
# 11                    Homo sapiens                             Maybe
# 12                    Homo sapiens                               Yes
# 13                    Homo sapiens                               Yes
# 14                    Homo sapiens                               Yes
# 15                    Homo sapiens                               Yes
# 17                    Homo sapiens                               Yes
# 19                    Homo sapiens                               Yes
# 21                    Homo sapiens                               Yes
# 22      Homo sapiens; Mus musculus                             Maybe
# 24                    Homo sapiens                               Yes
# 25                    Homo sapiens                               Yes
# 26                    Homo sapiens                               Yes
# 27                    Homo sapiens                               Yes
# 28      Mus musculus; Homo sapiens                               Yes
# 29                    Homo sapiens                               Yes
# 30                    Homo sapiens                               Yes
# 31  Homo sapiens; Escherichia coli                               Yes
# 32                    Homo sapiens                               Yes
# 33                    Homo sapiens                               Yes
# 34      Homo sapiens; Mus musculus                               Yes
# 35                    Homo sapiens                             Maybe
#
#                                    Other matched data Presenter  \
# 0   GSM5065201: H3K27ac_HiChIP_IFN_mOPC_rep2\nGSM5...
# 1   GSM5425946: aHiChIP PR T0\nGSM5425945: aHiChIP...
# 2   GSM5028231: Jurkat HiChIP\nGSM5028228: SJMPAL0...
# 3   GSM4735773: A673_siCT-Dh1_72h_HiChIP_CTCF_Rep1...
# 5   GSM5629821: KD\nGSM5629820: WT\nGSM4743725: M1...
# 6   GSM5171871: Day10_CD19_H3K27ac_rep2\nGSM517186...
# 7   GSM5281678: MB157pInd20EBF1_10dox_SMC1_HiChIP\...
# 8   GSM5455281: SUCCS1_siEA_96h_HiChIP\nGSM5455278...
# 9   GSM4053398: LS513 H3K27ac HiChIP\nGSM4053399: ...
# 10  GSM5431873: HiChIP: EBNA2- (P3HR1) EBV infecte...
# 11  GSM4221673: Ewing sarcoma sample EW150\nGSM525...
# 12  GSM5420290: RNA Pol. II HiChIP Auxin+ rep1\nGS...
# 13  GSM5515078: HiChIP AHDC1/GIBBIN KO3\nGSM551508...
# 14  GSM5571213: H3K27ac_HiChIP_OCI-Ly7_control_rep...
# 15  GSM4053400: SW620 H3K27ac HiChIP\nGSM4053397: ...
# 17  GSM5066593: RERFLCAI_HiChIP_H3K27ac\nGSM506659...
# 19  GSM4633103: Pulmonary artery endothelial cells...
# 21  GSM4563963: H524 Hi-ChIP\nGSM4563960: H2066 Hi...
# 22  GSM5526450: 2102Ep_HiMeDIP\nGSM5526451: E14_Hi...
# 24  GSM3444790: H3K27ac-CTL1-HiChIP-seq\nGSM344479...
# 25  GSM4735778: A673_siSA2-Dh6_72h_HiChIP_CTCF_Rep...
# 26               GSM5159894: Hudep2_D3_H3K27AC_HiCHIP
# 27  GSM5769506: HICHIP_no_DOX_rep3\nGSM5769503: HI...
# 28  GSM5533484: HiChIP_SPT6_LNA_V5\nGSM5533482: Hi...
# 29  GSM5229039: VCaP_DMSO_4h_CTCF (HiChIP-seq)\nGS...
# 30  GSM5515080: HiChIP WT2\nGSM5515077: HiChIP AHD...
# 31  GSM4804909: HiChIP-H3K27ac_day-3_rep-1\nGSM480...
# 32  GSM5059682: HiChIP SMC1A A673 STAG2 WT Replica...
# 33  GSM4782224: VCAP_H3K27ac_HiChIP_DHT_24hr\nGSM4...
# 34  GSM5379698: HiChIP_H3K27ac_WT\nGSM5379695: HiC...
# 35  GSM5403564: ChIC_GM12878_IgG_Rep1\nGSM5403558:...
#
#                  Date Added
# 0   <class 'datetime.date'>
# 1   <class 'datetime.date'>
# 2   <class 'datetime.date'>
# 3   <class 'datetime.date'>
# 5   <class 'datetime.date'>
# 6   <class 'datetime.date'>
# 7   <class 'datetime.date'>
# 8   <class 'datetime.date'>
# 9   <class 'datetime.date'>
# 10  <class 'datetime.date'>
# 11  <class 'datetime.date'>
# 12  <class 'datetime.date'>
# 13  <class 'datetime.date'>
# 14  <class 'datetime.date'>
# 15  <class 'datetime.date'>
# 17  <class 'datetime.date'>
# 19  <class 'datetime.date'>
# 21  <class 'datetime.date'>
# 22  <class 'datetime.date'>
# 24  <class 'datetime.date'>
# 25  <class 'datetime.date'>
# 26  <class 'datetime.date'>
# 27  <class 'datetime.date'>
# 28  <class 'datetime.date'>
# 29  <class 'datetime.date'>
# 30  <class 'datetime.date'>
# 31  <class 'datetime.date'>
# 32  <class 'datetime.date'>
# 33  <class 'datetime.date'>
# 34  <class 'datetime.date'>
# 35  <class 'datetime.date'>

# %% [markdown]
# ## Save the Output File

# %%
# determining the current year, month and day
today = date.today()
date_str = today.strftime("%Y_%m_%d")

# determining current hour and minute
now = datetime.now()
time_str = now.strftime("%H_%M")

# setting the output filename
output = os.path.join(outdir, "GEO_Compare.{}_{}".format(date_str, time_str))

# %%
differences_df.to_excel(output+".xlsx", index=False)
