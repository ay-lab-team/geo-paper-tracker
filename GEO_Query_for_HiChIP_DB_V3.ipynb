# %%
import argparse
from Bio import Entrez

import os 
import pandas as pd
from datetime import date
from datetime import datetime
import numpy as np
import re
from metapub import FindIt
from metapub.convert import pmid2doi
from metapub.convert import doi2pmid
from metapub import PubMedFetcher

import ssl
ssl._create_default_https_context = ssl._create_unverified_context
# Out:
# 2022-03-09 11:46:43 Cardiffs-MacBook.local metapub.config[91908] WARNING NCBI_API_KEY was not set.

# %% [markdown]
# ## Query the NCBI database

# %%
# use one of the following search queries/filters
filters = "HiChIP[All Fields] AND \"gse\"[Filter]" # the whole notebook will take around 7 min to run
# filters = "HiChIP[All Fields] AND (\"gse\"[Filter] AND (\"Homo sapiens\"[Organism] OR \"Mus musculus\"[Organism]))
# filters = "HiChIP[All Fields] AND (\"Homo sapiens\"[Organism] AND \"gse\"[Filter])"
# filters = "HiChIP[All Fields] AND (\"Homo sapiens\"[Organism] AND \"published last year\"[Filter]) AND \"gse\"[Filter]" # 2 min

# set a dummy email 
Entrez.email = "zjiang@lji.org"

# query the NCBI database 
search_result = Entrez.esearch(db="gds", retmax=10000, term=filters)
result = Entrez.read(search_result)

# creating a regex to extract pubmed IDs
PubMedIds_pattern = re.compile('[0123456789]+')

# %%
# parse the results into a dataframe 
dictionary_lst = []
for Id in result["IdList"]:
    handle = Entrez.esummary(db="gds", id=Id, retmode="xml") # get summary of this entry on GEO datasets
    entry = Entrez.parse(handle)
    for column in entry:
        dictionary_lst.append(column)
df = pd.DataFrame(dictionary_lst)

# %%
df.head()
# Out:
#   Item         Id  Accession GDS  \
# 0   []  200180198  GSE180198
# 1   []  200180194  GSE180194
# 2   []  200173872  GSE173872
# 3   []  200173871  GSE173871
# 4   []  200173843  GSE173843
#
#                                                title  \
# 0  EWSR1-ATF1 dependent 3D connectivity regulates...
# 1  EWSR1-ATF1 dependent 3D connectivity regulates...
# 2  EBF1 nuclear repositioning instructs chromatin...
# 3  EBF1 nuclear repositioning instructs chromatin...
# 4  EBF1 nuclear repositioning instructs chromatin...
#
#                                              summary          GPL     GSE  \
# 0  This SuperSeries is composed of the SubSeries ...        20301  180198
# 1  Chimeric proteins resulting from chromosomal t...        20301  180194
# 2  This SuperSeries is composed of the SubSeries ...  24676;18573  173872
# 3  Purpose: To investigate the mechanisms of 3D g...        18573  173871
# 4  Purpose: To investigate the mechanisms of 3D g...        18573  173843
#
#           taxon entryType  ...  \
# 0  Homo sapiens       GSE  ...
# 1  Homo sapiens       GSE  ...
# 2  Homo sapiens       GSE  ...
# 3  Homo sapiens       GSE  ...
# 4  Homo sapiens       GSE  ...
#
#                                         ExtRelations n_samples SeriesTitle  \
# 0                                                 []       147
# 1  [{'RelationType': 'SRA', 'TargetObject': 'SRP3...         4
# 2                                                 []       233
# 3  [{'RelationType': 'SRA', 'TargetObject': 'SRP3...         4
# 4  [{'RelationType': 'SRA', 'TargetObject': 'SRP3...         2
#
#   PlatformTitle PlatformTaxa SamplesTaxa  \
# 0
# 1
# 2
# 3
# 4
#
#                                    PubMedIds Projects  \
# 0                                         []       []
# 1                                         []       []
# 2  [IntegerElement(35182476, attributes={})]       []
# 3  [IntegerElement(35182476, attributes={})]       []
# 4  [IntegerElement(35182476, attributes={})]       []
#
#                                              FTPLink GEO2R
# 0  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE180nn...    no
# 1  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE180nn...    no
# 2  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE173nn...   yes
# 3  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE173nn...   yes
# 4  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE173nn...   yes
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Cleaning the Paper Names and Converting from PMID to DOI

# %%
dictionary_lst = []
for Id in result["IdList"]:
    
    handle = Entrez.esummary(db="gds", id=Id, retmode="xml")
    entry = Entrez.parse(handle)
    
    for column in entry:
        paper_title = column['title']
        new_paper_title = ''
        last_word = re.split('\s|[.]', paper_title)[-1]
        last_two_words = re.split('\s|[.]', paper_title)[-2:]
        
        # remove ".[HiChIP]", ". [HiChIP]", or "(HiChIP)" in paper titles using steps below
        if ('[' in last_word and ']' in last_word) or \
                ('(' in last_word and ')' in last_word):
            new_paper_title = re.split('\s|[.]', paper_title)[0:-1]
            new_paper_title = ' '.join(new_paper_title)
            new_paper_title = new_paper_title.strip()
            if new_paper_title.endswith('.'): # remove the last period in paper title
                new_paper_title = new_paper_title[:-1]
                
        # remove ".[Hi ChIP]", ". [Hi ChIP]", or "[Bead Array]" in paper titles using steps below
        elif ('[' in last_two_words[0] and ']' in last_two_words[1]) or \
                    ('(' in last_two_words[0] and ')' in last_two_words[1]):
            new_paper_title = re.split('\s|[.]', paper_title)[0:-2]
            new_paper_title = ' '.join(new_paper_title)
            new_paper_title = new_paper_title.strip()
            if new_paper_title.endswith('.'): # remove the last period in paper title
                new_paper_title = new_paper_title[:-1]
                
        elif paper_title.endswith('.'):
            new_paper_title = paper_title[:-1] 
            
        else:
            new_paper_title = paper_title
            
        new_paper_title = new_paper_title.replace("\xa0", " ") # remove no-break space
        column['title'] = new_paper_title
        
        # convert PMID to DOI, some have no PMID so empty string
        string = str(column['PubMedIds'])
        pdf_url = ""
        PubMedIds = PubMedIds_pattern.findall(string)
        
        if len(PubMedIds) > 0:
            DOI = pmid2doi(PubMedIds[0])
            column['PubMedIds'] = DOI
        else: column['PubMedIds'] = ""
        dictionary_lst.append(column)
        
df = pd.DataFrame(dictionary_lst)

# %% [markdown]
# ## Reformat the Columns for Google Sheet Compatibility

# %%
df = pd.DataFrame(dictionary_lst)

# drop extra columns
drop_cols = ['Item', 'Id', 'GDS', 'GPL', 'GSE', 'entryType', 'ptechType',
             'valType', 'SSInfo', 'subsetInfo', 'suppFile', 'Relations', 'ExtRelations',
             'n_samples', 'SeriesTitle', 'PlatformTitle', 'PlatformTaxa', 'SamplesTaxa',
             'Projects', 'FTPLink', 'GEO2R']
df.drop(drop_cols, inplace=True, axis=1)

# rename columns
rename_cols = {"Accession":"GEO / Data link", "PubMedIds":"DOI", "title":"Paper Title",
               "taxon":"Organism", "gdsType":"Any other information", "PDAT":"Year",
               "Samples":"Other matched data"}
df.rename(columns=rename_cols, inplace=True)

# extract just the year
df["Year"] = df["Year"].str[:4]

# add index for merging
df['index'] = np.arange(len(df))

# fill na with empty values
df.fillna("",inplace=True)

# adding missing columns with empty values
df["Journal"] = ""
df["Authors"] = ""
df["Tissue/Cell Line"] = ""
df["Presenter"] = ""
df["Potential HiChIP"] = ""

# %% [markdown]
# ## Assigning Potential HiChIP Samples

# %% [markdown]
# Filter out samples with no HiChIP mention and assigned Yes or Maybe to all others

# %%
col = df["Other matched data"]
lst = []
index = 0
for row in col:
    
    temp = []
    state = False
    
    # Check for the term HiChIP in the title
    for ele in row: 
        if ("HiChIP".casefold() in ele["Title"].casefold()) or \
                ("Hi-ChIP".casefold() in ele["Title"].casefold()):
            state = True
    
    # keep samples with HiChIP and mark "Yes"
    if state == True: 
            for ele in row:
                if ("HiChIP".casefold() in ele["Title"].casefold()) or \
                        ("Hi-ChIP".casefold() in ele["Title"].casefold()):
                    temp.append(ele["Accession"] + ": " + ele["Title"])
            temp_str = "\n".join(temp)
            df.at[index, "Potential HiChIP"] = "Yes"

    # otherwise, keep all GSM samples and mark "Maybe"
    else: 
        for ele in row:
            temp.append(ele["Accession"] + ": " + ele["Title"])
        temp_str = "\n".join(temp)
        df.at[index,"Potential HiChIP"]="Maybe"
    lst.append(temp_str)
    index += 1
    
df["Other matched data"] = list(lst)

# %% [markdown]
# ## Merge Rows with the Same Paper Title

# %%
aggregation_functions = {'Paper Title':'first', 'DOI':'max', 'Journal':'first', 'Authors':'first', 'Year':'first', 'GEO / Data link':lambda x: '\n'.join(x),
       'Any other information':lambda x: '\n'.join(x), 'Organism':'first', 'Tissue/Cell Line':'first',
       'Potential HiChIP':'first', 'Other matched data':lambda x: '\n'.join(x), 'Presenter':'first'}
df_grouped = df.groupby(df['Paper Title']).aggregate(aggregation_functions)

# %% [markdown]
# ## Fetch Journal Name and First Author of Each Paper and Add https to DOI

# %%
jounrnal_lst = []
authors_lst = []
fetch = PubMedFetcher()
for DOI in df_grouped['DOI']:
    try:
        PMID = doi2pmid(DOI)
        article = fetch.article_by_pmid(PMID)
        jounrnal_lst.append(article.journal)
        authors_lst.append(article.authors[0].split()[0] + " et al.")
    except:
        jounrnal_lst.append("")
        authors_lst.append("")
df_grouped['Journal'] = jounrnal_lst
df_grouped['Authors'] = authors_lst

# %%
# add https address to DOI (for easy access)
df_grouped.loc[(df_grouped['DOI'] != ''), 'DOI'] = 'https://doi.org/' + df_grouped.loc[(df_grouped['DOI'] != ''), 'DOI']

# %% [markdown]
# ## Note the Date Added, Set Output Path, and Save the Final Output File

# %%
# make an output directory
outdir = 'results/hichip_db/'
os.makedirs(outdir, exist_ok=True)

# %%
# determining the current year, month and day
today = date.today()
date_str = today.strftime("%Y_%m_%d")

# determining current hour and minute
now = datetime.now()
time_str = now.strftime("%H_%M")

# setting the output filename
output = os.path.join(outdir, "GEO_Query.{}_{}".format(date_str, time_str))

# %%
# add a column that notes the added date
df_grouped['Date Added'] = date_str.replace('_', '-')
reorder = ['Paper Title', 'Journal', 'Authors', 'Year', 'DOI', 'GEO / Data link', 'Any other information',
           'Organism', 'Tissue/Cell Line', 'Other matched data', 'Presenter', 'Date Added']
df_grouped = df_grouped.loc[:, reorder]

# %%
df_grouped.to_excel(output + ".xlsx", index=False)

# %%
df_grouped
# Out:
#                                                                                           Paper Title  \
# Paper Title
# 3D genome landscapes of primary effusion lympho...  3D genome landscapes of primary effusion lymph...
# A Foxp3 mutation drives Th2 effector function i...  A Foxp3 mutation drives Th2 effector function ...
# A primed immune transcriptional program is acti...  A primed immune transcriptional program is act...
# A small set of accessible enhancers enables bre...  A small set of accessible enhancers enables br...
# A topological atlas reveals layers of genome re...  A topological atlas reveals layers of genome r...
# ...                                                                                               ...
# Widespread Long-range Cis-Regulatory Elements i...  Widespread Long-range Cis-Regulatory Elements ...
# YY1 is a structural regulator of enhancer-promo...  YY1 is a structural regulator of enhancer-prom...
# YY1 regulates DNA-DNA interaction                                   YY1 regulates DNA-DNA interaction
# cLoops2: a full-stack comprehensive analytical ...  cLoops2: a full-stack comprehensive analytical...
# ecDNA hubs drive cooperative intermolecular onc...  ecDNA hubs drive cooperative intermolecular on...
#
#                                                               Journal  \
# Paper Title
# 3D genome landscapes of primary effusion lympho...         Nat Commun
# A Foxp3 mutation drives Th2 effector function i...
# A primed immune transcriptional program is acti...             Neuron
# A small set of accessible enhancers enables bre...  Nucleic Acids Res
# A topological atlas reveals layers of genome re...               Cell
# ...                                                               ...
# Widespread Long-range Cis-Regulatory Elements i...         Nat Plants
# YY1 is a structural regulator of enhancer-promo...               Cell
# YY1 regulates DNA-DNA interaction
# cLoops2: a full-stack comprehensive analytical ...  Nucleic Acids Res
# ecDNA hubs drive cooperative intermolecular onc...             Nature
#
#                                                              Authors  Year  \
# Paper Title
# 3D genome landscapes of primary effusion lympho...       Wang et al.  2020
# A Foxp3 mutation drives Th2 effector function i...                    2018
# A primed immune transcriptional program is acti...     Meijer et al.  2022
# A small set of accessible enhancers enables bre...     Zaurin et al.  2021
# A topological atlas reveals layers of genome re...  Johnstone et al.  2020
# ...                                                              ...   ...
# Widespread Long-range Cis-Regulatory Elements i...      Ricci et al.  2019
# YY1 is a structural regulator of enhancer-promo...  Weintraub et al.  2017
# YY1 regulates DNA-DNA interaction                                     2020
# cLoops2: a full-stack comprehensive analytical ...        Cao et al.  2021
# ecDNA hubs drive cooperative intermolecular onc...       Hung et al.  2020
#
#                                                                                              DOI  \
# Paper Title
# 3D genome landscapes of primary effusion lympho...    https://doi.org/10.1038/s41467-020-20136-w
# A Foxp3 mutation drives Th2 effector function i...
# A primed immune transcriptional program is acti...  https://doi.org/10.1016/j.neuron.2021.12.034
# A small set of accessible enhancers enables bre...          https://doi.org/10.1093/nar/gkab1125
# A topological atlas reveals layers of genome re...    https://doi.org/10.1016/j.cell.2020.07.030
# ...                                                                                          ...
# Widespread Long-range Cis-Regulatory Elements i...     https://doi.org/10.1038/s41477-019-0547-0
# YY1 is a structural regulator of enhancer-promo...    https://doi.org/10.1016/j.cell.2017.11.008
# YY1 regulates DNA-DNA interaction
# cLoops2: a full-stack comprehensive analytical ...          https://doi.org/10.1093/nar/gkab1233
# ecDNA hubs drive cooperative intermolecular onc...    https://doi.org/10.1038/s41586-021-04116-8
#
#                                                          GEO / Data link  \
# Paper Title
# 3D genome landscapes of primary effusion lympho...             GSE136090
# A Foxp3 mutation drives Th2 effector function i...             GSE112176
# A primed immune transcriptional program is acti...  GSE166177\nGSE166179
# A small set of accessible enhancers enables bre...             GSE179666
# A topological atlas reveals layers of genome re...             GSE133928
# ...                                                                  ...
# Widespread Long-range Cis-Regulatory Elements i...             GSE120304
# YY1 is a structural regulator of enhancer-promo...    GSE99521\nGSE99519
# YY1 regulates DNA-DNA interaction                              GSE128106
# cLoops2: a full-stack comprehensive analytical ...             GSE179010
# ecDNA hubs drive cooperative intermolecular onc...  GSE159986\nGSE159985
#
#                                                                                 Any other information  \
# Paper Title
# 3D genome landscapes of primary effusion lympho...  Genome binding/occupancy profiling by high thr...
# A Foxp3 mutation drives Th2 effector function i...  Expression profiling by high throughput sequen...
# A primed immune transcriptional program is acti...  Other\nGenome binding/occupancy profiling by h...
# A small set of accessible enhancers enables bre...  Expression profiling by high throughput sequen...
# A topological atlas reveals layers of genome re...  Genome binding/occupancy profiling by high thr...
# ...                                                                                               ...
# Widespread Long-range Cis-Regulatory Elements i...  Expression profiling by high throughput sequen...
# YY1 is a structural regulator of enhancer-promo...  Expression profiling by high throughput sequen...
# YY1 regulates DNA-DNA interaction                   Genome binding/occupancy profiling by high thr...
# cLoops2: a full-stack comprehensive analytical ...                                              Other
# ecDNA hubs drive cooperative intermolecular onc...  Genome binding/occupancy profiling by high thr...
#
#                                                                       Organism  \
# Paper Title
# 3D genome landscapes of primary effusion lympho...                Homo sapiens
# A Foxp3 mutation drives Th2 effector function i...                Mus musculus
# A primed immune transcriptional program is acti...                Mus musculus
# A small set of accessible enhancers enables bre...                Homo sapiens
# A topological atlas reveals layers of genome re...                Homo sapiens
# ...                                                                        ...
# Widespread Long-range Cis-Regulatory Elements i...                    Zea mays
# YY1 is a structural regulator of enhancer-promo...  Homo sapiens; Mus musculus
# YY1 regulates DNA-DNA interaction                                 Homo sapiens
# cLoops2: a full-stack comprehensive analytical ...                Homo sapiens
# ecDNA hubs drive cooperative intermolecular onc...                Homo sapiens
#
#                                                    Tissue/Cell Line  \
# Paper Title
# 3D genome landscapes of primary effusion lympho...
# A Foxp3 mutation drives Th2 effector function i...
# A primed immune transcriptional program is acti...
# A small set of accessible enhancers enables bre...
# A topological atlas reveals layers of genome re...
# ...                                                             ...
# Widespread Long-range Cis-Regulatory Elements i...
# YY1 is a structural regulator of enhancer-promo...
# YY1 regulates DNA-DNA interaction
# cLoops2: a full-stack comprehensive analytical ...
# ecDNA hubs drive cooperative intermolecular onc...
#
#                                                                                    Other matched data  \
# Paper Title
# 3D genome landscapes of primary effusion lympho...  GSM4040942: BCBL1_HiChIP (2 replicates)\nGSM40...
# A Foxp3 mutation drives Th2 effector function i...  GSM3059350: Treg_WT HiChIP H3K27ac biological ...
# A primed immune transcriptional program is acti...  GSM5065199: H3K27ac_HiChIP_IFN_mOPC_rep1\nGSM5...
# A small set of accessible enhancers enables bre...  GSM5425946: aHiChIP PR T0\nGSM5425945: aHiChIP...
# A topological atlas reveals layers of genome re...  GSM3930281: MGH1904_HiChIP\nGSM3930275: BRD316...
# ...                                                                                               ...
# Widespread Long-range Cis-Regulatory Elements i...  GSM4284450: HiChIP B73 leaf H3K4me3\nGSM428445...
# YY1 is a structural regulator of enhancer-promo...  GSM2774003: HiChIP_mES_C3_UT_H3K27ac_rep1\nGSM...
# YY1 regulates DNA-DNA interaction                   GSM3664990: HiChIP YY1 rep1\nGSM3664993: HiChI...
# cLoops2: a full-stack comprehensive analytical ...  GSM5403564: ChIC_GM12878_IgG_Rep1\nGSM5403558:...
# ecDNA hubs drive cooperative intermolecular onc...  GSM5334235: SNU16_dCas9_KRAB_H3K27ac_HiChIP_re...
#
#                                                    Presenter  Date Added
# Paper Title
# 3D genome landscapes of primary effusion lympho...            2022-03-09
# A Foxp3 mutation drives Th2 effector function i...            2022-03-09
# A primed immune transcriptional program is acti...            2022-03-09
# A small set of accessible enhancers enables bre...            2022-03-09
# A topological atlas reveals layers of genome re...            2022-03-09
# ...                                                      ...         ...
# Widespread Long-range Cis-Regulatory Elements i...            2022-03-09
# YY1 is a structural regulator of enhancer-promo...            2022-03-09
# YY1 regulates DNA-DNA interaction                             2022-03-09
# cLoops2: a full-stack comprehensive analytical ...            2022-03-09
# ecDNA hubs drive cooperative intermolecular onc...            2022-03-09
#
# [125 rows x 12 columns]
